# %% [markdown]
# # ETL Pipeline Preparation
# Follow the instructions below to help you create your ETL pipeline.
# ### 1. Import libraries and load datasets.
# - Import Python libraries
# - Load `messages.csv` into a dataframe and inspect the first few lines.
# - Load `categories.csv` into a dataframe and inspect the first few lines.

# %%
# import libraries
import pandas as pd

# %%
# load messages dataset
messages = pd.read_csv("messages.csv")
messages.head()
# Out:
#    id                                            message  \
# 0   2  Weather update - a cold front from Cuba that c...
# 1   7            Is the Hurricane over or is it not over
# 2   8                    Looking for someone but no name
# 3   9  UN reports Leogane 80-90 destroyed. Only Hospi...
# 4  12  says: west side of Haiti, rest of the country ...
#
#                                             original   genre
# 0  Un front froid se retrouve sur Cuba ce matin. ...  direct
# 1                 Cyclone nan fini osinon li pa fini  direct
# 2  Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 3  UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 4  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
# load categories dataset
categories = pd.read_csv("categories.csv")
categories.tail()
# Out:
#           id                                         categories
# 26243  30261  related-0;request-0;offer-0;aid_related-0;medi...
# 26244  30262  related-0;request-0;offer-0;aid_related-0;medi...
# 26245  30263  related-1;request-0;offer-0;aid_related-0;medi...
# 26246  30264  related-1;request-0;offer-0;aid_related-1;medi...
# 26247  30265  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 2. Merge datasets.
# - Merge the messages and categories datasets using the common id
# - Assign this combined dataset to `df`, which will be cleaned in the following steps

# %%
# merge datasets
df = pd.merge(messages,categories,on=['id'])
df.tail()
# Out:
#           id                                            message original  \
# 26381  30261  The training demonstrated how to enhance micro...      NaN
# 26382  30262  A suitable candidate has been selected and OCH...      NaN
# 26383  30263  Proshika, operating in Cox's Bazar municipalit...      NaN
# 26384  30264  Some 2,000 women protesting against the conduc...      NaN
# 26385  30265  A radical shift in thinking came about as a re...      NaN
#
#       genre                                         categories
# 26381  news  related-0;request-0;offer-0;aid_related-0;medi...
# 26382  news  related-0;request-0;offer-0;aid_related-0;medi...
# 26383  news  related-1;request-0;offer-0;aid_related-0;medi...
# 26384  news  related-1;request-0;offer-0;aid_related-1;medi...
# 26385  news  related-1;request-0;offer-0;aid_related-0;medi...

# %% [markdown]
# ### 3. Split `categories` into separate category columns.
# - Split the values in the `categories` column on the `;` character so that each value becomes a separate column. You'll find [this method](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.Series.str.split.html) very helpful! Make sure to set `expand=True`.
# - Use the first row of categories dataframe to create column names for the categories data.
# - Rename columns of `categories` with new column names.

# %%
# create a dataframe of the 36 individual category columns
categories = categories['categories'].str.split(";",expand=True)
categories.tail()
# Out:
#               0          1        2              3               4   \
# 26243  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 26244  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 26245  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 26246  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 26247  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#                        5                    6           7           8   \
# 26243  medical_products-0  search_and_rescue-0  security-0  military-0
# 26244  medical_products-0  search_and_rescue-0  security-0  military-0
# 26245  medical_products-0  search_and_rescue-0  security-0  military-0
# 26246  medical_products-0  search_and_rescue-0  security-0  military-1
# 26247  medical_products-0  search_and_rescue-0  security-0  military-0
#
#                   9        ...                    26                      27  \
# ...

# %%
# select the first row of the categories dataframe
row = categories.iloc[0]
# print (row)
# print (type(row))
# use this row to extract a list of new column names for categories.
# one way is to apply a lambda function that takes everything 
# up to the second to last character of each string with slicing
category_colnames = row.apply(lambda x: x[:-2])
print(category_colnames)
# Out:
# 0                    related
# 1                    request
# 2                      offer
# 3                aid_related
# 4               medical_help
# 5           medical_products
# 6          search_and_rescue
# 7                   security
# 8                   military
# 9                child_alone
# 10                     water
# 11                      food
# 12                   shelter
# 13                  clothing
# 14                     money
# 15            missing_people
# 16                  refugees
# 17                     death
# 18                 other_aid
# 19    infrastructure_related
# 20                 transport
# 21                 buildings
# 22               electricity
# 23                     tools
# 24                 hospitals
# 25                     shops
# 26               aid_centers
# 27      other_infrastructure
# 28           weather_related
# 29                    floods
# 30                     storm
# 31                      fire
# ...

# %%
# rename the columns of `categories`
categories.columns = category_colnames
categories.tail()
# Out:
# 0        related    request    offer    aid_related    medical_help  \
# 26243  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 26244  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 26245  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 26246  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 26247  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
# 0        medical_products    search_and_rescue    security    military  \
# 26243  medical_products-0  search_and_rescue-0  security-0  military-0
# 26244  medical_products-0  search_and_rescue-0  security-0  military-0
# 26245  medical_products-0  search_and_rescue-0  security-0  military-0
# 26246  medical_products-0  search_and_rescue-0  security-0  military-1
# 26247  medical_products-0  search_and_rescue-0  security-0  military-0
#
# 0        child_alone       ...           aid_centers    other_infrastructure  \
# ...

# %% [markdown]
# ### 4. Convert category values to just numbers 0 or 1.
# - Iterate through the category columns in df to keep only the last character of each string (the 1 or 0). For example, `related-0` becomes `0`, `related-1` becomes `1`. Convert the string to a numeric value.
# - You can perform [normal string actions on Pandas Series](https://pandas.pydata.org/pandas-docs/stable/text.html#indexing-with-str), like indexing, by including `.str` after the Series. You may need to first convert the Series to be of type string, which you can do with `astype(str)`.

# %%
for column in categories:
    # set each value to be the last character of the string
    categories[column] = categories[column].apply(lambda x: x[-1:])
    
    #print (categories[column])
    # convert column from string to numeric
    categories[column] = categories[column].astype('int64')
categories.tail()
# Out:
# 0      related  request  offer  aid_related  medical_help  medical_products  \
# 26243        0        0      0            0             0                 0
# 26244        0        0      0            0             0                 0
# 26245        1        0      0            0             0                 0
# 26246        1        0      0            1             0                 0
# 26247        1        0      0            0             0                 0
#
# 0      search_and_rescue  security  military  child_alone      ...        \
# 26243                  0         0         0            0      ...
# 26244                  0         0         0            0      ...
# 26245                  0         0         0            0      ...
# 26246                  0         0         1            0      ...
# 26247                  0         0         0            0      ...
#
# 0      aid_centers  other_infrastructure  weather_related  floods  storm  \
# ...

# %% [markdown]
# ### 5. Replace `categories` column in `df` with new category columns.
# - Drop the categories column from the df dataframe since it is no longer needed.
# - Concatenate df and categories data frames.

# %%
# drop the original categories column from `df`

df.drop(['categories'],axis=1,inplace=True)

df.tail()
# Out:
#           id                                            message original genre
# 26381  30261  The training demonstrated how to enhance micro...      NaN  news
# 26382  30262  A suitable candidate has been selected and OCH...      NaN  news
# 26383  30263  Proshika, operating in Cox's Bazar municipalit...      NaN  news
# 26384  30264  Some 2,000 women protesting against the conduc...      NaN  news
# 26385  30265  A radical shift in thinking came about as a re...      NaN  news

# %%
# concatenate the original dataframe with the new `categories` dataframe
#df = pd.concat([df,categories],axis=1) This is incorrect as it performs outer join
df = pd.concat([df, categories], axis=1, join='inner', sort=False)
df.tail()
# Out:
#           id                                            message original  \
# 26243  30107  "The pattern is always the same: steal, loot, ...      NaN
# 26244  30108  Sirajganj, Bangladesh. When the rain-swollen J...      NaN
# 26245  30109  Damage to the Nacala rail corridor by the rain...      NaN
# 26246  30110  Thus, an armed drone strike in Pakistan, a Nig...      NaN
# 26247  30111  This year's 16 Days theme, "From Peace in the ...      NaN
#
#       genre  related  request  offer  aid_related  medical_help  \
# 26243  news        0        0      0            0             0
# 26244  news        0        0      0            0             0
# 26245  news        1        0      0            0             0
# 26246  news        1        0      0            1             0
# 26247  news        1        0      0            0             0
#
#        medical_products      ...        aid_centers  other_infrastructure  \
# ...

# %% [markdown]
# ### 6. Remove duplicates.
# - Check how many duplicates are in this dataset.
# - Drop the duplicates.
# - Confirm duplicates were removed.

# %%
# check number of duplicates
duplicateRowsDF = df[df.duplicated()] # Selecting duplicate rows (except the first occurence) based on all columns 
print (duplicateRowsDF)
# Out:
#           id                                            message  \
# 716      862  What is the address of the radio station? I as...
# 1414    1652  please we need water, food and tents, we have ...
# 1416    1652  please we need water, food and tents, we have ...
# 4653    5265  (Delmas 33 Charboniere infomatyon s'il vous pl...
# 4978    5643  Good evening. we are writing to ask you for a ...
# 4979    5643  Good evening. we are writing to ask you for a ...
# 5102    5776  I would like some more informations about trav...
# 5588    6327  jel2  Acte 5: 29 2chr7 Lev11 Ecl9 Ecl4 jos5 ch...
# 5589    6327  jel2  Acte 5: 29 2chr7 Lev11 Ecl9 Ecl4 jos5 ch...
# 5639    6393    I'd like to sign up in the 4636 program please
# 5641    6393    I'd like to sign up in the 4636 program please
# 5731    6492           I'd like to know an email to find a job
# 5756    6515  I would like to find some informations about t...
# 5757    6515  I would like to find some informations about t...
# ...

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

len(df)
# Out:
# 26207

# %%
# check number of duplicates
len(duplicateRowsDF)
# Out:
# 41

# %%
#Checking the values of related
df['related'].unique()
# Out:
# array([1, 0, 2])

# %%
#Remove unwanted data from the related column
df.related.replace(2,1,inplace=True)

# %% [markdown]
# ### 7. Save the clean dataset into an sqlite database.
# You can do this with pandas [`to_sql` method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html) combined with the SQLAlchemy library. Remember to import SQLAlchemy's `create_engine` in the first cell of this notebook to use it below.

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///InsertDatabaseName.db')
#df.to_sql('InsertTableName', engine, index=False) #Incorrect as you have performed outer join while concatenating
#df.to_sql('InsertTableName1', engine, index=False) # Incorrect as you have dropped na values from the dataset
#df.to_sql('InsertTableName2', engine, index=False) # Needs correction on the related column of df (Bcz it has value 2)
df.to_sql('InsertTableName3', engine, index=False)

# %% [markdown]
# ### 8. Use this notebook to complete `etl_pipeline.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database based on new datasets specified by the user. Alternatively, you can complete `etl_pipeline.py` in the classroom on the `Project Workspace IDE` coming later.
